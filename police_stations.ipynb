# %%
from bs4 import BeautifulSoup as bs
import urllib
import numpy as np
import pandas as pd
import csv

# %%
BASE = "http://www.mapdevelopers.com/what-county-am-i-in.php?address="

# %%
with open("stations.csv", 'r') as f:
    st = list(csv.reader(f, delimiter=','))

# %%
print(st[:3])
# Out:
# [['id', 'state.abbrev', 'station', 'city', 'county', 'zipcode'], ['4816', 'MO', 'ADAIR COUNTY SHERIFF OFFICE', '', '', ''], ['4817', 'MO', 'ALTON POLICE DEPT', '', '', '']]

# %%
headers = st[1]
station_data = np.array(st[1:])

# %%
for station in station_data[:1,2]:
    adr = BASE + station.replace(' ', '%20')
    s_r = urllib.request.urlopen(adr).read()
    station_soup = bs(s_r)
    print(adr)
# Out:
# http://www.mapdevelopers.com/what-county-am-i-in.php?address=ADAIR%20COUNTY%20SHERIFF%20OFFICE

# %%
ids = {
    'city': 'display_city',
    'county': 'display_county',
    'zipcode': 'display_zip',
    'latitude': 'display_lat',
    'longitude': 'display_lng'
}

# %%
url = 'http://www.mapdevelopers.com/what-county-am-i-in.php?address=ADAIR%20COUNTY%20SHERIFF%20OFFICE'

# %%
r = urllib.request.urlopen(url).read()

# %%
soup = bs(r)
# Out:
# //anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file //anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
#   <meta content="Fred Metterhausen" name="Author"/>
#   <meta content="mapdevelopers.com" name="Publisher"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="30 days" name="revisit-after"/>
#   <meta content="global" name="distribution"/>
#   <meta content="general" name="rating"/>
#   <meta content="english" name="Content-Language"/>
#   <meta content="" name="Keywords"/>
#   <meta content="Use your current location to find what county you are in. You can also click on the map or enter an address to find your county." name="Description"/>
#   <title>
#    What County am I in - Find your county
#   </title>
# ...

# %%
soup.find('div',{'id' : ids['county']})
# Out:
# <div class="col-sm-4 col-md-4" id="display_county"></div>

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Firefox()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# //anaconda/lib/python3.6/site-packages/selenium/webdriver/common/service.py in start(self)
#      73             elif err.errno == errno.EACCES:
# ---> 74                 raise WebDriverException(
#      75                     "'%s' executable may have wrong permissions. %s" % (
#
# //anaconda/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     706                                 errread, errwrite,
# --> 707                                 restore_signals, start_new_session)
#     708         except:
#
# ...
